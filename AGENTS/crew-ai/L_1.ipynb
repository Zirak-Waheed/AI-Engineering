# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
from dotenv import find_dotenv, load_dotenv


os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'
load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  description=tasks_config['task_breakdown']['description'],
  agent=project_planning_agent,
  expected_output=tasks_config['task_breakdown']['expected_output']
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  description=tasks_config['time_resource_estimation']['description'],
  agent=estimation_agent,
  expected_output=tasks_config['time_resource_estimation']['expected_output']
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  description=tasks_config['resource_allocation']['description'],
  output_pydantic=ProjectPlan # This is the structured output we want
  expected_output=tasks_config['resource_allocation']['expected_output']
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 8be24434-dd27-48a6-bee8-2401eec005a8                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: a6eca5cb-306a-4fcf-9c84-a148e3b3132c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Website Project Detailed Task Breakdown                                                                    │
# │                                                                                                                 │
# │  **Project Overview**: Create a website for a small business, ensuring that it is responsive, user-friendly,    │
# │  and optimized for performance and SEO.                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Task List                                                                                                  │
# │                                                                                                                 │
# │  | Task No. | Task Description | Scope | Assigned To | Start Date | End Date | Dependencies | Deliverables |    │
# │  |----------|------------------|-------|-------------|------------|----------|---------------|--------------|   │
# │  | 1        | Create Project Plan | Develop a detailed project plan including scope, timeline, and resource     │
# │  allocation. | Plan timelines, resources required, set milestones | John Doe | 01-Nov-2023 | 05-Nov-2023 |      │
# │  Project Plan Document |                                                                                        │
# │  | 2        | Requirement Gathering | Interview stakeholders to gather detailed project requirements and        │
# │  expectations. | Gather requirements for design, functionality, and content | John Doe, Bob Smith |             │
# │  06-Nov-2023 | 12-Nov-2023 | Requirement Specification Document |                                               │
# │  | 3        | Create Wireframes | Design initial wireframes for the main pages of the website. | Draft          │
# │  wireframes for Homepage, About Us, Services, Contact Us, Blog, Testimonials | Bob Smith | 13-Nov-2023 |        │
# │  19-Nov-2023 | Wireframe Documents |                                                                            │
# │  | 4        | Review Wireframes | Present wireframes to stakeholders for feedback and make revisions as         │
# │  needed. | Conduct a review session for approval | John Doe, Bob Smith | 20-Nov-2023 | 22-Nov-2023 | Approved   │
# │  Wireframes |                                                                                                   │
# │  | 5        | Create Responsive Design | Develop the responsive design ensuring mobile and desktop              │
# │  compatibility. | Use CSS frameworks to ensure usability on all devices | Bob Smith | 23-Nov-2023 |             │
# │  30-Nov-2023 | Responsive Design Files |                                                                        │
# │  | 6        | Implement UI/UX Design | Create modern user interface with an appealing look. Focus on            │
# │  aesthetics and functionality. | Develop mockups and style guides | Bob Smith | 01-Dec-2023 | 08-Dec-2023 |     │
# │  UI/UX Design Mockups |                                                                                         │
# │  | 7        | Develop Navigation System | Set up user-friendly navigation menus and structure. | Ensure         │
# │  intuitive access to all pages | Jane Doe | 09-Dec-2023 | 15-Dec-2023 | Navigation System Structure |           │
# │  | 8        | Create "About Us" Page | Develop content and layout for the "About Us" page. | Include company    │
# │  history and values | Jane Doe | 16-Dec-2023 | 18-Dec-2023 | "About Us" Page |                                  │
# │  | 9        | Create "Services" Page | Design and develop content for "Services" showcasing business            │
# │  offerings. | Include detailed service descriptions | Jane Doe | 19-Dec-2023 | 23-Dec-2023 | "Services" Page |  │
# │  | 10       | Create "Contact Us" Page | Implement responsive form and integrate Google Map for contact info.   │
# │  | Ensure user-friendly communication options | Jane Doe | 24-Dec-2023 | 29-Dec-2023 | "Contact Us" Page |      │
# │  | 11       | Develop Blog Section | Create a section for posting blogs and updates about industry news. |      │
# │  Include easy-to-use content management system | Jane Doe | 30-Dec-2023 | 05-Jan-2024 | Blog Functionality |    │
# │  | 12       | Implement SEO Strategy | Optimize site for search engines and ensure fast loading times. |        │
# │  Conduct keyword research and implement SEO best practices | Jane Doe | 06-Jan-2024 | 12-Jan-2024 | SEO         │
# │  Optimization Report |                                                                                          │
# │  | 13       | Integrate Social Media | Add links and sharing functionalities for social media platforms. |      │
# │  Ensure easy access for visitors to share content | Jane Doe | 13-Jan-2024 | 15-Jan-2024 | Social Media         │
# │  Integration |                                                                                                  │
# │  | 14       | Create Testimonials Section | Design and implement a section for customer testimonials. |         │
# │  Include features for easy submission and display | Jane Doe | 16-Jan-2024 | 18-Jan-2024 | Testimonials         │
# │  Section |                                                                                                      │
# │  | 15       | Quality Assurance Testing | Conduct comprehensive testing of functionality and design. | Ensure   │
# │  everything operates as expected on all devices | Alice Johnson, Tom Brown | 19-Jan-2024 | 25-Jan-2024 |        │
# │  Testing Report |                                                                                               │
# │  | 16       | Final Reviews and Revisions | Conduct final reviews with stakeholders and make necessary          │
# │  corrections. | Ensure satisfaction with final product | John Doe | 26-Jan-2024 | 30-Jan-2024 | Final Approval  │
# │  |                                                                                                              │
# │  | 17       | Deployment | Deploy the website onto the live server and conduct post-launch checks. | Ensure     │
# │  hosting, domain setup and functionality | Jane Doe | 31-Jan-2024 | 02-Feb-2024 | Live Website |                │
# │  | 18       | Project Closure | Complete project documentation and gather final feedback for closure. | Ensure  │
# │  all processes are finalized | John Doe | 03-Feb-2024 | 05-Feb-2024 | Project Closure Document |                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Timeline Visualization (Gantt Chart)                                                                       │
# │                                                                                                                 │
# │  ```plaintext                                                                                                   │
# │  +----------------------+-----------------------------------------------------+                                 │
# │  | Task No. | Task Name   | Nov-2023            | Dec-2023            | Jan-2024            | Feb-2024          │
# │  |                                                                                                              │
# │  +----------|-------------|---------------------|---------------------|---------------------|-----------------  │
# │  -+                                                                                                             │
# │  | 01       | Project Plan| #####               |                     |                     |                   │
# │  |                                                                                                              │
# │  | 02       | Gather Requirements |            #####               |                     |                      │
# │  |                  |                                                                                           │
# │  | 03       | Wireframes  |                     | #####               |                     |                   │
# │  |                                                                                                              │
# │  | 04       | Review Wireframes |              |  ##                |                     |                  |  │
# │  | 05       | Responsive Design |              |     #####           |                     |                    │
# │  |                                                                                                              │
# │  | 06       | UI/UX Design |                     |         #####       |                     |                  │
# │  |                                                                                                              │
# │  | 07       | Navigation System |                     |         #####      |                     |              │
# │  |                                                                                                              │
# │  | 08       | About Us Page |                    |                 ### |                     |                  │
# │  |                                                                                                              │
# │  | 09       | Services Page |                    |                 ### |                     |                  │
# │  |                                                                                                              │
# │  | 10       | Contact Us Page |                  |                 ### |                     |                  │
# │  |                                                                                                              │
# │  | 11       | Blog Section |                     |                 ### |                     |                  │
# │  |                                                                                                              │
# │  | 12       | SEO Strategy |                     |                     |  #####              |                  │
# │  |                                                                                                              │
# │  | 13       | Social Media |                     |                     |      ###            |                  │
# │  |                                                                                                              │
# │  | 14       | Testimonials |                     |                     |      ##             |                  │
# │  |                                                                                                              │
# │  | 15       | QA Testing   |                     |                     |                     |         #####    │
# │  |                                                                                                              │
# │  | 16       | Final Review |                     |                     |                     |         ###      │
# │  |                                                                                                              │
# │  | 17       | Deployment   |                     |                     |                     |            ##    │
# │  |                                                                                                              │
# │  | 18       | Closure      |                     |                     |                     |                  │
# │  ###  |                                                                                                         │
# │  +----------|-------------|---------------------|---------------------|---------------------|-----------------  │
# │  -+                                                                                                             │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ### Key Points:                                                                                                │
# │  - Each task is designed to be individually manageable with clear deliverables.                                 │
# │  - Timelines are spaced to allow for collaboration, feedback, and revisions where necessary.                    │
# │  - Dependencies must be managed to ensure smooth transitions between tasks, particularly between design and     │
# │  development phases.                                                                                            │
# │  - Quality Assurance steps included to ensure the final product is polished before launch.                      │
# │                                                                                                                 │
# │  By breaking down the project into these smaller, manageable tasks, the team can efficiently track progress     │
# │  and ensure all requirements are met, leading to successful website deployment for the small business.          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │  ID: f03bc864-4768-4a43-bcf1-dcf3ecd19eec                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Website Project Estimation Report                                                                            │
# │                                                                                                                 │
# │  **Project Overview**: This document presents the estimations for the Website project intended for a small      │
# │  business. The project emphasizes responsive design, user-friendliness, SEO optimization, and performance       │
# │  efficiency.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Detailed Estimation for Each Task                                                                          │
# │                                                                                                                 │
# │  | Task No. | Task Description                | Estimated Time (Days) | Resources Required                      │
# │  | Effort (Total Person-Hours) | Risk/Uncertainties                                     |                       │
# │  |----------|----------------------------------|------------------------|-------------------------------------  │
# │  --------------------|------------------------------|--------------------------------------------------------|  │
# │  | 1        | Create Project Plan             | 5                      | Project Manager (1x), Planning Tools   │
# │  | 40 hours                     | Potential stakeholder availability                      |                     │
# │  | 2        | Requirement Gathering            | 7                      | Project Manager (1x), Business        │
# │  Analyst (1x)            | 56 hours                     | Requirement changes from stakeholders                 │
# │  |                                                                                                              │
# │  | 3        | Create Wireframes               | 7                      | UX/UI Designer (1x)                    │
# │  | 56 hours                     | Need for iterations based on feedback                   |                     │
# │  | 4        | Review Wireframes               | 3                      | Project Manager (1x), UX/UI Designer   │
# │  (1x)              | 24 hours                     | Delays in feedback from stakeholders                    |   │
# │  | 5        | Create Responsive Design        | 8                      | UX/UI Designer (1x), Front-end         │
# │  Developer (1x), Coding Resources| 64 hours                     | Compatibility issues with different devices   │
# │  |                                                                                                              │
# │  | 6        | Implement UI/UX Design          | 7                      | UX/UI Designer (1x), Front-end         │
# │  Developer (1x)          | 56 hours                     | Risk of design not aligning with user requirements    │
# │  |                                                                                                              │
# │  | 7        | Develop Navigation System        | 7                      | Front-end Developer (1x)              │
# │  | 56 hours                     | Complexity of navigation structure could lead to delays|                      │
# │  | 8        | Create "About Us" Page         | 3                      | Content Creator (1x), Front-end         │
# │  Developer (1x)         | 24 hours                     | Content approval from stakeholders                     │
# │  |                                                                                                              │
# │  | 9        | Create "Services" Page         | 5                      | Content Creator (1x), Front-end         │
# │  Developer (1x)         | 40 hours                     | Incomplete service descriptions causing delays         │
# │  |                                                                                                              │
# │  | 10       | Create "Contact Us" Page       | 6                      | Front-end Developer (1x), Content       │
# │  Creator (1x)         | 48 hours                     | Potential issues with form functionality                 │
# │  |                                                                                                              │
# │  | 11       | Develop Blog Section            | 7                      | Back-end Developer (1x), Content       │
# │  Creator (1x)          | 56 hours                     | Integration of CMS may surface technical challenges     │
# │  |                                                                                                              │
# │  | 12       | Implement SEO Strategy          | 7                      | SEO Specialist (1x), Content Creator   │
# │  (1x)              | 56 hours                     | Continuous changes in SEO best practices                |   │
# │  | 13       | Integrate Social Media          | 3                      | Front-end Developer (1x)               │
# │  | 24 hours                     | APIs of social platforms may change                     |                     │
# │  | 14       | Create Testimonials Section      | 3                      | Front-end Developer (1x), Content     │
# │  Creator (1x)         | 24 hours                     | User submissions for testimonials might be low           │
# │  |                                                                                                              │
# │  | 15       | Quality Assurance Testing        | 7                      | QA Analyst (1x), Front-end Developer  │
# │  (1x)              | 56 hours                     | Potential bugs or issues discovered could affect timeline|  │
# │  | 16       | Final Reviews and Revisions     | 5                      | Project Manager(1x), UX/UI             │
# │  Designer(1x)                | 40 hours                     | Last-minute changes may arise                     │
# │  |                                                                                                              │
# │  | 17       | Deployment                      | 3                      | DevOps Engineer (1x)                   │
# │  | 24 hours                     | Hosting/server issues can delay deployment             |                      │
# │  | 18       | Project Closure                 | 2                      | Project Manager (1x)                   │
# │  | 16 hours                     | Gathering final feedback might take longer than expected|                     │
# │                                                                                                                 │
# │  ### Summary of Risks and Uncertainties                                                                         │
# │  - **Stakeholder Availability**: Delays could occur if stakeholders are unavailable for feedback or approval,   │
# │  especially during critical phases like requirement gathering and final reviews.                                │
# │  - **Changing Requirements**: As the project evolves, additional requirements or changes may emerge, leading    │
# │  to scope creep.                                                                                                │
# │  - **Technical Challenges**: Integration of different tools and platforms (SEO, CMS, Social Media) may pose     │
# │  unforeseen challenges, affecting timelines.                                                                    │
# │  - **Testing Phase**: Bugs identified during quality assurance could require significant rework, impacting end  │
# │  dates.                                                                                                         │
# │  - **Content Creation Delays**: Required content may not be submitted on time, affecting page creation and      │
# │  overall site completion.                                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Conclusion                                                                                                 │
# │  This estimation report provides a comprehensive overview of the time, resources, and effort required for each  │
# │  task in the Website project  aimed at delivering a high-quality product to the small business client. Close    │
# │  monitoring of dependencies and proactive risk management will be essential to maintain timelines and budget    │
# │  adherence.                                                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: 9e25e431-c1ce-47f1-b8d8-bd667effa3fe                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Task: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  tasks=[TaskEstimate(task_name='Create Project Plan', estimated_time_hours=40.0, required_resources=['John      │
# │  Doe']), TaskEstimate(task_name='Requirement Gathering', estimated_time_hours=56.0, required_resources=['John   │
# │  Doe', 'Bob Smith']), TaskEstimate(task_name='Create Wireframes', estimated_time_hours=56.0,                    │
# │  required_resources=['Bob Smith']), TaskEstimate(task_name='Review Wireframes', estimated_time_hours=24.0,      │
# │  required_resources=['John Doe', 'Bob Smith']), TaskEstimate(task_name='Create Responsive Design',              │
# │  estimated_time_hours=64.0, required_resources=['Bob Smith']), TaskEstimate(task_name='Implement UI/UX          │
# │  Design', estimated_time_hours=56.0, required_resources=['Bob Smith']), TaskEstimate(task_name='Develop         │
# │  Navigation System', estimated_time_hours=56.0, required_resources=['Jane Doe']),                               │
# │  TaskEstimate(task_name="Create 'About Us' Page", estimated_time_hours=24.0, required_resources=['Jane Doe']),  │
# │  TaskEstimate(task_name="Create 'Services' Page", estimated_time_hours=40.0, required_resources=['Jane Doe']),  │
# │  TaskEstimate(task_name="Create 'Contact Us' Page", estimated_time_hours=48.0, required_resources=['Jane        │
# │  Doe']), TaskEstimate(task_name='Develop Blog Section', estimated_time_hours=56.0, required_resources=['Jane    │
# │  Doe']), TaskEstimate(task_name='Implement SEO Strategy', estimated_time_hours=56.0, required_resources=['Jane  │
# │  Doe']), TaskEstimate(task_name='Integrate Social Media', estimated_time_hours=24.0, required_resources=['Jane  │
# │  Doe']), TaskEstimate(task_name='Create Testimonials Section', estimated_time_hours=24.0,                       │
# │  required_resources=['Jane Doe']), TaskEstimate(task_name='Quality Assurance Testing',                          │
# │  estimated_time_hours=56.0, required_resources=['Alice Johnson', 'Tom Brown']), TaskEstimate(task_name='Final   │
# │  Reviews and Revisions', estimated_time_hours=40.0, required_resources=['John Doe']),                           │
# │  TaskEstimate(task_name='Deployment', estimated_time_hours=24.0, required_resources=['Jane Doe']),              │
# │  TaskEstimate(task_name='Project Closure', estimated_time_hours=16.0, required_resources=['John Doe'])]         │
# │  milestones=[Milestone(milestone_name='Planning Phase', tasks=['1', '2']), Milestone(milestone_name='Design     │
# │  Phase', tasks=['3', '4', '5', '6']), Milestone(milestone_name='Development Phase', tasks=['7', '8', '9',       │
# │  '10', '11', '12', '13', '14']), Milestone(milestone_name='Testing Phase', tasks=['15']),                       │
# │  Milestone(milestone_name='Finalization', tasks=['16', '17', '18'])]                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ╭────────────────────────── Tracing Preference Saved ──────────────────────────╮
# │                                                                              │
# │  Info: Tracing has been disabled.                                            │
# │                                                                              │
# │  Your preference has been saved. Future Crew/Flow executions will not        │
# │  collect traces.                                                             │
# │                                                                              │
# │  To enable tracing later, do any one of these:                               │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 8be24434-dd27-48a6-bee8-2401eec005a8                                                                       │
# │  Final Output: {"tasks":[{"task_name":"Create Project                                                           │
# │  Plan","estimated_time_hours":40.0,"required_resources":["John Doe"]},{"task_name":"Requirement                 │
# │  Gathering","estimated_time_hours":56.0,"required_resources":["John Doe","Bob Smith"]},{"task_name":"Create     │
# │  Wireframes","estimated_time_hours":56.0,"required_resources":["Bob Smith"]},{"task_name":"Review               │
# │  Wireframes","estimated_time_hours":24.0,"required_resources":["John Doe","Bob Smith"]},{"task_name":"Create    │
# │  Responsive Design","estimated_time_hours":64.0,"required_resources":["Bob Smith"]},{"task_name":"Implement     │
# │  UI/UX Design","estimated_time_hours":56.0,"required_resources":["Bob Smith"]},{"task_name":"Develop            │
# │  Navigation System","estimated_time_hours":56.0,"required_resources":["Jane Doe"]},{"task_name":"Create 'About  │
# │  Us' Page","estimated_time_hours":24.0,"required_resources":["Jane Doe"]},{"task_name":"Create 'Services'       │
# │  Page","estimated_time_hours":40.0,"required_resources":["Jane Doe"]},{"task_name":"Create 'Contact Us'         │
# │  Page","estimated_time_hours":48.0,"required_resources":["Jane Doe"]},{"task_name":"Develop Blog                │
# │  Section","estimated_time_hours":56.0,"required_resources":["Jane Doe"]},{"task_name":"Implement SEO            │
# │  Strategy","estimated_time_hours":56.0,"required_resources":["Jane Doe"]},{"task_name":"Integrate Social        │
# │  Media","estimated_time_hours":24.0,"required_resources":["Jane Doe"]},{"task_name":"Create Testimonials        │
# │  Section","estimated_time_hours":24.0,"required_resources":["Jane Doe"]},{"task_name":"Quality Assurance        │
# │  Testing","estimated_time_hours":56.0,"required_resources":["Alice Johnson","Tom Brown"]},{"task_name":"Final   │
# │  Reviews and Revisions","estimated_time_hours":40.0,"required_resources":["John                                 │
# │  Doe"]},{"task_name":"Deployment","estimated_time_hours":24.0,"required_resources":["Jane                       │
# │  Doe"]},{"task_name":"Project Closure","estimated_time_hours":16.0,"required_resources":["John                  │
# │  Doe"]}],"milestones":[{"milestone_name":"Planning Phase","tasks":["1","2"]},{"milestone_name":"Design          │
# │  Phase","tasks":["3","4","5","6"]},{"milestone_name":"Development                                               │
# │  Phase","tasks":["7","8","9","10","11","12","13","14"]},{"milestone_name":"Testing                              │
# │  Phase","tasks":["15"]},{"milestone_name":"Finalization","tasks":["16","17","18"]}]}                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0014
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          9049           5733                     0               3316
#
#    successful_requests
# 0                    3

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Project Plan',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Requirement Gathering',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['John Doe', 'Bob Smith']},
#   {'task_name': 'Create Wireframes',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Review Wireframes',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['John Doe', 'Bob Smith']},
#   {'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 64.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement UI/UX Design',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'About Us' Page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'Services' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 48.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop Blog Section',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement SEO Strategy',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create Testimonials Section',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Reviews and Revisions',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Deployment',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Project Closure',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']}],
#  'milestones': [{'milestone_name': 'Planning Phase', 'tasks': ['1', '2']},
#   {'milestone_name': 'Design Phase', 'tasks': ['3', '4', '5', '6']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['7', '8', '9', '10', '11', '12', '13', '14']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['15']},
#   {'milestone_name': 'Finalization', 'tasks': ['16', '17', '18']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_1d4bb th {
#   font-size: 120%;
# }
# #T_1d4bb  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_1d4bb" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d4bb_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_1d4bb_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_1d4bb_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d4bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d4bb_row0_col0" class="data row0 col0" >Create Project Plan</td>
#       <td id="T_1d4bb_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_1d4bb_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d4bb_row1_col0" class="data row1 col0" >Requirement Gathering</td>
#       <td id="T_1d4bb_row1_col1" class="data row1 col1" >56.000000</td>
#       <td id="T_1d4bb_row1_col2" class="data row1 col2" >['John Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d4bb_row2_col0" class="data row2 col0" >Create Wireframes</td>
#       <td id="T_1d4bb_row2_col1" class="data row2 col1" >56.000000</td>
#       <td id="T_1d4bb_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d4bb_row3_col0" class="data row3 col0" >Review Wireframes</td>
#       <td id="T_1d4bb_row3_col1" class="data row3 col1" >24.000000</td>
#       <td id="T_1d4bb_row3_col2" class="data row3 col2" >['John Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1d4bb_row4_col0" class="data row4 col0" >Create Responsive Design</td>
#       <td id="T_1d4bb_row4_col1" class="data row4 col1" >64.000000</td>
#       <td id="T_1d4bb_row4_col2" class="data row4 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1d4bb_row5_col0" class="data row5 col0" >Implement UI/UX Design</td>
#       <td id="T_1d4bb_row5_col1" class="data row5 col1" >56.000000</td>
#       <td id="T_1d4bb_row5_col2" class="data row5 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1d4bb_row6_col0" class="data row6 col0" >Develop Navigation System</td>
#       <td id="T_1d4bb_row6_col1" class="data row6 col1" >56.000000</td>
#       <td id="T_1d4bb_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1d4bb_row7_col0" class="data row7 col0" >Create 'About Us' Page</td>
#       <td id="T_1d4bb_row7_col1" class="data row7 col1" >24.000000</td>
#       <td id="T_1d4bb_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1d4bb_row8_col0" class="data row8 col0" >Create 'Services' Page</td>
#       <td id="T_1d4bb_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_1d4bb_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1d4bb_row9_col0" class="data row9 col0" >Create 'Contact Us' Page</td>
#       <td id="T_1d4bb_row9_col1" class="data row9 col1" >48.000000</td>
#       <td id="T_1d4bb_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1d4bb_row10_col0" class="data row10 col0" >Develop Blog Section</td>
#       <td id="T_1d4bb_row10_col1" class="data row10 col1" >56.000000</td>
#       <td id="T_1d4bb_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1d4bb_row11_col0" class="data row11 col0" >Implement SEO Strategy</td>
#       <td id="T_1d4bb_row11_col1" class="data row11 col1" >56.000000</td>
#       <td id="T_1d4bb_row11_col2" class="data row11 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1d4bb_row12_col0" class="data row12 col0" >Integrate Social Media</td>
#       <td id="T_1d4bb_row12_col1" class="data row12 col1" >24.000000</td>
#       <td id="T_1d4bb_row12_col2" class="data row12 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1d4bb_row13_col0" class="data row13 col0" >Create Testimonials Section</td>
#       <td id="T_1d4bb_row13_col1" class="data row13 col1" >24.000000</td>
#       <td id="T_1d4bb_row13_col2" class="data row13 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1d4bb_row14_col0" class="data row14 col0" >Quality Assurance Testing</td>
#       <td id="T_1d4bb_row14_col1" class="data row14 col1" >56.000000</td>
#       <td id="T_1d4bb_row14_col2" class="data row14 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1d4bb_row15_col0" class="data row15 col0" >Final Reviews and Revisions</td>
#       <td id="T_1d4bb_row15_col1" class="data row15 col1" >40.000000</td>
#       <td id="T_1d4bb_row15_col2" class="data row15 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1d4bb_row16_col0" class="data row16 col0" >Deployment</td>
#       <td id="T_1d4bb_row16_col1" class="data row16 col1" >24.000000</td>
#       <td id="T_1d4bb_row16_col2" class="data row16 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_1d4bb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1d4bb_row17_col0" class="data row17 col0" >Project Closure</td>
#       <td id="T_1d4bb_row17_col1" class="data row17 col1" >16.000000</td>
#       <td id="T_1d4bb_row17_col2" class="data row17 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_cc05d th {
#   font-size: 120%;
# }
# #T_cc05d  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_cc05d" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc05d_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_cc05d_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc05d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc05d_row0_col0" class="data row0 col0" >Planning Phase</td>
#       <td id="T_cc05d_row0_col1" class="data row0 col1" >['1', '2']</td>
#     </tr>
#     <tr>
#       <th id="T_cc05d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc05d_row1_col0" class="data row1 col0" >Design Phase</td>
#       <td id="T_cc05d_row1_col1" class="data row1 col1" >['3', '4', '5', '6']</td>
#     </tr>
#     <tr>
#       <th id="T_cc05d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc05d_row2_col0" class="data row2 col0" >Development Phase</td>
#       <td id="T_cc05d_row2_col1" class="data row2 col1" >['7', '8', '9', '10', '11', '12', '13', '14']</td>
#     </tr>
#     <tr>
#       <th id="T_cc05d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc05d_row3_col0" class="data row3 col0" >Testing Phase</td>
#       <td id="T_cc05d_row3_col1" class="data row3 col1" >['15']</td>
#     </tr>
#     <tr>
#       <th id="T_cc05d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc05d_row4_col0" class="data row4 col0" >Finalization</td>
#       <td id="T_cc05d_row4_col1" class="data row4 col1" >['16', '17', '18']</td>
#     </tr>
#   </tbody>
# </table>
